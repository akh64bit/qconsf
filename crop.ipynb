# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import inference as inf
import cv2

# %%
x=inf.infer('person2.jpg','Elbows','Knees')

# %%
plt.figure(figsize=(16,8))
plt.imshow(x)
plt.show()
